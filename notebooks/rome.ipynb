# %%
from os.path import join as path_join
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from collections import Counter
from bs4 import BeautifulSoup
from os.path import isfile
import pandas as pd
import numpy as np
import matplotlib
import warnings
import requests
import operator
import json
import sys
import os
import re

pd.options.display.float_format = '{:.4g}'.format

import plotly.graph_objs as go
import plotly.offline as py
from plotly import tools

py.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
CITY = "rome"
DEBUG = True

# %%
if DEBUG:
    warnings.filterwarnings('ignore')

# %%
def load_json(fn):
    with open(fn, "r") as f:
        return json.load(f)

nb_settings = load_json("notebooks_settings.json")  
city_center = nb_settings[CITY]['city_center']
opposite_city = nb_settings[CITY]['opposite_city']
#osm_area_key = nb_settings[CITY]['osm_area_key']
osm_area_key = 'area'
language = nb_settings[CITY]['language']

# %%
project_path = "/Users/pavel/Sources/python/concepts/insta/"

scenes_path_template = "cv_sandbox/photo_tagger/scenes_{}.json"
scenes_path = scenes_path_template.format(CITY)
scenes_opposite_path = scenes_path_template.format(opposite_city)

photos_path_template = "public/photos/{}/"
photos_path = photos_path_template.format(CITY)
photos_opposite_path = photos_path_template.format(opposite_city)

adresses_path = "scripts/adresses/adresses_{}.csv".format(CITY)

wiki_path = "wiki/"
osm_path = "osm/"

token_file = "mapbox.token"
MAPBOX_TOKEN = open(token_file, "r").readlines()[0]

# %%
fn1 = path_join(project_path, scenes_path.format(CITY))
data1 = load_json(fn1)

# %%
path = path_join(project_path, photos_path)
loc_file = list(map(lambda x: x.strip().split(","), open(path_join(path, "loc_info.csv"), "r").readlines()[1:]))
id2loc = {x[0]: x[1] for x in loc_file}

# %%
def relevant_places(tag, n_top=100):
    d = {}
    for loc in list(data1.keys()):
        loc_val = 0
        for photo in data1[loc]:
            val = 0
            if tag in data1[loc][photo]['categories']:
                val = data1[loc][photo]['categories'][tag]
            loc_val += float(val)
        if loc_val > 0:
            d[loc] = loc_val
    return sorted(d.items(), key=operator.itemgetter(1), reverse=True)[:n_top]

# %% [markdown]
# ## Locations popularity

# %%
def title(s):
    return s.title()

def area_normalize_ru(s):
    stopword = "район"
    
    abbreviations = {"административный округ": "АО"}
    s = s.replace(stopword, "").strip()
    for x in abbreviations:
        s = s.replace(x, abbreviations[x]).strip()
    return s


def street_normalize_ru(s):
    abbreviations = {'Улица': 'Ул.', 
                     'Проспект': 'Пр-т', 
                     'Набережная': 'Наб.', 
                     'Проезд': 'Пр-д', 
                     'Бульвар': 'Бул.',
                     'Площадь': 'Пл.'}
    for x in abbreviations:
        s = s.replace(x, abbreviations[x]).strip()
    return s

# %%
# FIXME: paths
project_path_new = '/Users/pavel/Sources/python/concepts/insta/public/'
adresses_dir = path_join(project_path_new, 'data/adresses/')
adresses_path = path_join(adresses_dir, 'adresses_{}.csv'.format(CITY))

geo_table = pd.read_csv(adresses_path, error_bad_lines=False)

geo_table = geo_table.drop_duplicates()

# %%
STREET_COLUMN = 'route'

geo_table[STREET_COLUMN] = list(map(title, 
                                    geo_table[STREET_COLUMN].tolist()))
if language == 'ru':
    geo_table[osm_area_key] = list(map(area_normalize_ru, 
                                      geo_table[osm_area_key].tolist()))
    geo_table[STREET_COLUMN] = list(map(street_normalize_ru, 
                                        geo_table[STREET_COLUMN].tolist()))

streets = geo_table[STREET_COLUMN].tolist()
areas = geo_table[osm_area_key].tolist()

street_locations_n = sorted(Counter(streets).items(), 
                             key=operator.itemgetter(1), reverse=True)

area_locations_n = sorted(Counter(areas).items(), 
                           key=operator.itemgetter(1), reverse=True)
###

TOP_AREAS_N = 10
TOP_STREETS_N = 100
TOP_STREETS_VIS = 20

areas = [x[0] for x in area_locations_n[1:TOP_AREAS_N+1]] 
area_activity = [x[1] for x in area_locations_n[1:TOP_AREAS_N+1]]

streets = [x[0] for x in street_locations_n[1:TOP_STREETS_N+1]]
map_streets = [x[0] for x in street_locations_n]
street_activity = [x[1] for x in street_locations_n[1:TOP_STREETS_N+1]]
map_streets_activity = [x[1] for x in street_locations_n]

# %%
geo_table['longtitude'] = geo_table['longtitude'].astype(float)
geo_table['latitude'] = geo_table['latitude'].astype(float)

avg_coords_table = geo_table[[STREET_COLUMN, 'longtitude','latitude']].groupby(STREET_COLUMN).agg(np.mean).reset_index()

locations_counter_table = geo_table[STREET_COLUMN].value_counts().reset_index()
locations_counter_table.columns = [STREET_COLUMN, 'counter']

streets_table = pd.merge(avg_coords_table, 
                         locations_counter_table, 
                         on=STREET_COLUMN).sort_values(by='counter', ascending=False)

streets_table = streets_table[streets_table[STREET_COLUMN] != 'None']

# %%
def city_map(lat, lon, streets, streets_locations_number):
    MARKER_SIZE = 17
    MARKER_OPACITY = 0.4
    MARKER_COLOR = 'red'
    ZOOM = 12
    MARGIN = dict(l=0, r=30, b=0, t=20)
    MAP_WIDTH = 700
    MAP_HEIGHT = 400
    MAX_MARKER_SIZE = 40
    MIN_MARKER_SIZE = 3
    MIN_LOCATIONS = 15
    
    labels = [x if streets_locations_number.iloc[j] > MIN_LOCATIONS
                   else "" for j, x in enumerate(streets_locations_number)]
    marker_sizes = [x if x < MAX_MARKER_SIZE else MAX_MARKER_SIZE 
                    for x in streets_locations_number]
    marker_sizes = [x if x > MIN_MARKER_SIZE else MIN_MARKER_SIZE
                    for x in marker_sizes]

    
    round3 = lambda x: round(float(x), 3)
    hover_template = "<i>{}</i><br>coords: {:.3f} {:.3f}<br>n_locations: {}"
    hover_func = lambda x, y, z, zz: hover_template.format(x, round3(y), round3(z), zz)
    scatter_hover = list(map(hover_func, streets, lat, lon, streets_locations_number))
    
    data = [go.Scattermapbox(
                lat=lat,
                lon=lon,
                mode='markers',
                marker=dict(
                    size=marker_sizes,
                    color=MARKER_COLOR,
                    opacity=MARKER_OPACITY),
                text=scatter_hover,
                hoverinfo='text')]

    layout = go.Layout(
                width=MAP_WIDTH,
                height=MAP_HEIGHT,
                hovermode='closest',
                margin=MARGIN, 
                showlegend=False,
                mapbox=dict(
                    accesstoken=MAPBOX_TOKEN,
                    center=dict(
                        lat=city_center[0],
                        lon=city_center[1]),
                    zoom=ZOOM,
                    style='light'))

    fig = dict(data=data, layout=layout)
    py.iplot(fig, show_link=False)    

city_map(streets_table['longtitude'].tolist(), 
         streets_table['latitude'].tolist(), 
         streets_table[STREET_COLUMN], 
         streets_table['counter'])
# Out:
# <div id="c6028084-e6fd-496a-b81d-d8fd70ba1831" style="height: 400px; width: 700px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c6028084-e6fd-496a-b81d-d8fd70ba1831", [{"hoverinfo": "text", "lat": [41.90583865045294, 41.90420041763549, 41.898913391773924, 41.91079089803637, 41.90287954990475, 41.89061297825, 41.85264196639444, 41.930973357606256, 41.89924516711875, 41.89603506830666, 41.89618345021428, 41.892557257853845, 41.89539239788182, 41.90472757279, 41.9017579033, 41.90529425596, 41.90095269137, 41.898197160989994, 41.93397713390001, 41.893212345500004, 41.815054114944445, 41.90850684209999, 41.9284845677125, 41.9072939989625, 41.906262777225, 41.89382166069999, 41.9335812128, 41.924524071300006, 41.89708015272857, 41.89559623955714, 41.89556008501428, 41.90906932627143, 41.89779213742857, 41.892221601349995, 41.90099370741667, 41.903703237933335, 41.90741316891667, 41.9419822301, 41.899983703483336, 41.908536328766665, 41.9045124146, 41.90593949893333, 41.89764943066667, 41.89877080106667, 41.92829558394, 41.899616949800006, 41.93422813626, 41.90051839798, 41.89177444164, 41.89289765668, 41.90534597094, 41.896097960400006, 41.93734491374, 41.90535037884, 41.87131464078, 41.897627566660006, 41.903349396799996, 41.9021534747, 41.90611996165, 41.902737215325004, 41.8994064456, 41.904421164125, 41.902568700125, 41.905734848550004, 41.89954363374999, 41.9000607098, 41.908915373125, 41.90864491905, 41.875835411875, 41.902164068475, 41.895777022225005, 41.894512129575006, 41.892409373999996, 41.897422013150006, 41.8942332921, 41.941861870375, 41.9316998516, 41.8949948625, 41.899208153100005, 41.8438311998, 41.89425286713333, 41.89766532543334, 41.899134585666665, 41.93889333333333, 41.9002839615, 41.8989752213, 41.93239966666666, 41.890255340866666, 41.893807752933334, 41.904249568333334, 41.93102663333334, 41.899518, 41.88121338883334, 41.8995588431, 41.9049002962, 41.8961345895, 41.89906130093333, 41.89261905906667, 41.894684959433334, 41.8870644912, 41.89643883643333, 41.93471307876667, 41.85059126636667, 41.901152413, 41.89597130923334, 41.8960957594, 41.95645153866667, 41.9338817841, 41.9513393487, 41.880950067700006, 41.899585923033335, 41.8917475444, 41.900315329166666, 41.90105271826667, 41.90539957199999, 41.92898327733334, 41.905109279166666, 41.85, 41.90680681, 41.90639810973333, 41.88321201653333, 41.933969491, 41.8938592859, 41.90013857809999, 41.92307058506666, 41.90075273636666, 41.85742150000001, 41.908297536633334, 41.900876022733335, 41.899008040000005, 41.90617608673333, 41.90461437346667, 41.91597008803333, 41.91089972213334, 41.889055, 41.903595300000006, 41.90020832645, 41.94495145725, 41.8852430128, 41.89796, 41.892269457750004, 41.91746675245, 41.9291569293, 41.8891114276, 41.9076394655, 41.8985805, 41.9105322889, 41.9093, 41.90229951795, 41.89559764185, 41.85285893895, 41.923344826, 41.85205522155, 41.8141372926, 41.905455, 41.928176651499996, 41.929469524249996, 41.828447752, 41.9011508354, 41.8979599563, 41.896924999999996, 41.93098096065, 41.94488670395, 41.883735441249996, 41.87794644725, 41.859044999999995, 41.899444444400004, 41.912386304, 41.9538413164, 41.92194219495, 41.88028018999999, 41.8088677616, 41.866776, 41.932582999999994, 41.9000526413, 41.9028693089, 41.864318, 41.85282155, 41.9009822522, 41.928931785050004, 41.907605546599996, 41.90578003515, 41.822876803949995, 41.90966416924999, 41.8941638889, 41.8997205254, 41.90080166665, 41.888120834649996, 41.9068454275, 41.89919836985, 41.905687703149994, 41.841225, 41.94866217975, 41.898279694850004, 41.91203945665, 41.88896858215, 41.8998901109, 41.862754267949995, 41.90513479495, 41.91898535475, 41.8813950503, 41.93665405829999, 41.9439872989, 41.89793495000001, 41.8521039182, 41.884903344099996, 41.90121925, 41.88806876335, 41.9430755424, 41.9385479969, 41.882355069599996, 41.8982929 ...

# %%
def street_area_combine_plot(streets_barchart_y, 
                             streets_barchart_x,
                             lat, lon,
                             areas_barchart_values, 
                             areas_piechart_labels):    
    HOLE = 0.5
    PULL = 0.05
    PIE_AREA_X = [0.1, 1.0]
    PIE_AREA_Y = [0.2, 0.8]
    BAR_CHART_OPACITY = 0.8
    BAR_CHART_COLOR = 'red'
    BAR_CHART_CM = "Wistia"
    BAR_CHART_LEGEND_X = 0.55
    BAR_CHART_LEGEND_Y = 0.0
    
    TICK_LEN = 4
    PLOT_HEIGHT = 350
    PLOT_WIDTH = 900
    BAR_CHART_AREA_X = [0, 0.25]
    BAR_CHART_AREA_Y = [0, 1.0]
    MARGIN = go.layout.Margin(l=220, t=15, b=15, r=0)
    
    BAR_CHART_FONT_COLOR = 'lightgrey'
    BAR_CHART_FONT_SIZE = 11
    PIE_CHART_FONT_COLOR = 'grey'
    PIE_CHART_FONT_SIZE = 11
    
    MIN_COLOR_VALUE = 0.20
    MAX_COLOR_VALUE = 0.60
    
    colormap = matplotlib.cm.get_cmap(BAR_CHART_CM)
    
    norm_val = np.linspace(MAX_COLOR_VALUE, 
                           MIN_COLOR_VALUE, 
                           len(areas_barchart_values))
    
    pieces_colors = list(map(lambda x: 
                             matplotlib.colors.rgb2hex(colormap(x)), 
                             norm_val))
    
    round3 = lambda x: round(float(x), 3)
    hover_format = lambda x, y, z: "{}<br>{:.3f} {:.3f}".format(x, round3(y), round3(z))
    bar_hover = list(map(hover_format, streets_barchart_y, lat, lon))
    
    data = [go.Bar(y=streets_barchart_y,
                    x=streets_barchart_x,
                    marker=dict(color=BAR_CHART_COLOR), 
                    orientation='h',
                    text=bar_hover,
                    hoverinfo='text',
                    opacity=BAR_CHART_OPACITY, 
                    showlegend=False),

            go.Pie(values=areas_barchart_values,
                    labels=areas_piechart_labels,
                    domain=dict(x=PIE_AREA_X, y=PIE_AREA_Y),
                    hoverinfo="label+percent+value",
                    textinfo='label+value', 
                    textposition='outside',
                    hole=HOLE,
                    sort=False,
                    textfont=dict(size=PIE_CHART_FONT_SIZE, 
                                  color=PIE_CHART_FONT_COLOR),
                    marker=dict(colors=pieces_colors), 
                    pull=PULL)]
    
    layout = go.Layout(height=PLOT_HEIGHT, width=PLOT_WIDTH,
                       showlegend=False, 
                       margin=MARGIN, 
                       hovermode='closest',
                       xaxis=dict(domain=BAR_CHART_AREA_X, 
                                  tickfont=dict(color=BAR_CHART_FONT_COLOR,
                                                size=BAR_CHART_FONT_SIZE)),
                       yaxis=dict(domain=BAR_CHART_AREA_Y, 
                                  autorange="reversed", 
                                  ticklen=TICK_LEN, 
                                  tickfont=dict(size=BAR_CHART_FONT_SIZE, 
                                                color=BAR_CHART_FONT_COLOR)))
    fig = go.Figure(data=data, layout=layout)
    py.iplot(fig, show_link=False)

    
N_AREAS_VISUALIZED = 5
N_STREETS_VISUALIZED = 20
OTHER_LABEL = "Other"

streets_table_shrinked = streets_table[:N_STREETS_VISUALIZED]
area_activity_shrinked = area_activity[:N_AREAS_VISUALIZED] + [sum(area_activity[N_AREAS_VISUALIZED+1:])]
areas_labels_shrinked = areas[:N_AREAS_VISUALIZED] + [OTHER_LABEL]

street_area_combine_plot(streets_table_shrinked[STREET_COLUMN],
                         streets_table_shrinked['counter'],
                         streets_table_shrinked['latitude'],
                         streets_table_shrinked['longtitude'],
                         area_activity_shrinked,
                         areas_labels_shrinked)
# Out:
# <div id="c80ee973-521c-4767-a928-b3dbeb2e6d5d" style="height: 350px; width: 900px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'c80ee973-521c-4767-a928-b3dbeb2e6d5d',
#             [{"hoverinfo": "text", "marker": {"color": "red"}, "opacity": 0.8, "orientation": "h", "showlegend": false, "text": ["Piazza Di Spagna<br>12.482 41.906", "Via Del Corso<br>12.479 41.904", "Piazza Navona<br>12.473 41.899", "Piazza Del Popolo<br>12.476 41.911", "Lungotevere Castello<br>12.466 41.903", "Piazza Del Colosseo<br>12.492 41.891", "Via Tuscolana<br>12.571 41.853", "Via Flaminia<br>12.470 41.931", "Piazza Della Rotonda<br>12.477 41.899", "Via Del Pellegrino<br>12.472 41.896", "Piazza Venezia<br>12.482 41.896", "Via Della Salara Vecchia<br>12.486 41.893", "Piazza Di San Marco<br>12.482 41.895", "Via Tomacelli<br>12.478 41.905", "Ponte Sant'Angelo<br>12.466 41.902", "Via Dei Condotti<br>12.481 41.905", "Piazza Di Trevi<br>12.483 41.901", "Via Del Governo Vecchio<br>12.470 41.898", "Viale Dello Stadio Olimpico<br>12.454 41.934", "Piazza Del Campidoglio<br>12.483 41.893"], "x": [51.0, 31.0, 23.0, 22.0, 21.0, 20.0, 18.0, 16.0, 16.0, 15.0, 14.0, 13.0, 11.0, 10.0, 10.0, 10.0, 10.0, 10.0, 9.0, 9.0], "y": ["Piazza Di Spagna", "Via Del Corso", "Piazza Navona", "Piazza Del Popolo", "Lungotevere Castello", "Piazza Del Colosseo", "Via Tuscolana", "Via Flaminia", "Piazza Della Rotonda", "Via Del Pellegrino", "Piazza Venezia", "Via Della Salara Vecchia", "Piazza Di San Marco", "Via Tomacelli", "Ponte Sant'Angelo", "Via Dei Condotti", "Piazza Di Trevi", "Via Del Governo Vecchio", "Viale Dello Stadio Olimpico", "Piazza Del Campidoglio"], "type": "bar", "uid": "5bf95da4-2af7-11e9-a212-3c15c2cf2370"}, {"domain": {"x": [0.1, 1.0], "y": [0.2, 0.8]}, "hole": 0.5, "hoverinfo": "label+percent+value", "labels": ["Municipio XV", "Municipio VII", "Municipio II", "None", "Municipio IV", "Other"], "marker": {"colors": ["#ffb100", "#ffba00", "#ffc706", "#ffd50e", "#ffe317", "#faed2d"]}, "pull": 0.05, "sort": false, "textfont": {"color": "grey", "size": 11}, "textinfo": "label+value", "textposition": "outside", "values": [84, 70, 61, 54, 30, 44], "type": "pie", "uid": "5bf95fac-2af7-11e9-a5d0-3c15c2cf2370"}],
#             {"height": 350, "hovermode": "closest", "margin": {"b": 15, "l": 220, "r": 0, "t": 15}, "showlegend": false, "width": 900, "xaxis": {"domain": [0, 0.25], "tickfont": {"color": "lightgrey", "size": 11}}, "yaxis": {"autorange": "reversed", "domain": [0, 1.0], "tickfont": {"color": "lightgrey", "size": 11}, "ticklen": 4}},
#             {"showLink": false, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('c80ee973-521c-4767-a928-b3dbeb2e6d5d',{});}).then(function(){Plotly.animate('c80ee973-521c-4767-a928-b3dbeb2e6d5d');})
#         });</script>

# %%
def trim(s, max_len=20):
    if len(s) <= max_len:
        return s
    else:
        s = s[:max_len].strip("_")
        return s + "..."

# %%
N_SCENES = 25
SELECTED_TAGS = ['library/indoor', 'restaurant', 'street', 'bar', 
                 'discotheque', 'promenade', 'museum/indoor', 'art_gallery', 
                 'bridge', 'dressing_room', 'picnic_area', 'beer_hall', 
                 'skyscraper', 'bookstore', 'closet', 'television_studio', 
                 'stadium/soccer', 'pub/indoor', 'industrial_area', 'art_studio',
                 'lawn', 'highway', 'coffee_shop', 'booth/indoor', 'martial_arts_gym']

def get_tags(mode, top_scenes=None):
    if mode == "top":
        return [x[0] for x in top_scenes]
    elif mode == "selected":
        return SELECTED_TAGS

# %%
def calculate_street_enviroment():
    locations_env = []
    for loc in list(data1.keys()):
        photo_env = []
        for photo in data1[loc]:
            photo_env.append(data1[loc][photo]['enviroment'])
            
        env_counter = dict(Counter(photo_env))
        
        street = geo_table[geo_table['id'] == int(loc)] \
                                    [STREET_COLUMN].tolist()
        
        if 'outdoor' in env_counter:
            outdoor_cn = env_counter['outdoor']
        else:
            outdoor_cn = 0
            
        if 'indoor' in env_counter:
            indoor_cn = env_counter['indoor']
        else:
            indoor_cn = 0
        
        if street and street[0] != 'None':
            locations_env.append([loc, outdoor_cn, 
                                  indoor_cn, 
                                  street[0]])
    locations_env = pd.DataFrame(locations_env)
    locations_env.columns = ['id', 'outdoor', 'indoor', 'street']
    return locations_env


def build_tags_table(tags, scene_data):
    dd = []
    for loc in list(scene_data.keys()):
        cn = Counter()
        location_data = scene_data[loc]
        for photo in location_data:
            photo_data = scene_data[loc][photo]['categories'].items()
            for category, val in photo_data:
                cn[category] += float(val) / len(location_data)
        dd.append([loc, cn])

    dd1 = []
    for x in dd:
        dd1.append([x[0]] + [x[1][tag] for tag in tags])

    tags_table = pd.DataFrame(dd1)
    tags_table.columns=["id"] + tags
    
    return tags_table

# %%
def tuple_to_str(t):
    return('{}, {}'.format(trim(t[0].replace("_", " ").strip()), t[1]))


def trim(s, max_len=20):
    if len(s) <= max_len:
        return s
    else:
        s = s[:max_len].strip("_")
        return s + "..."
    

def remove_stopwords(df, column, stopwords):
    for word in stopwords:
        df = df[df[column].map(lambda x: not word in x.lower().split())]
    return df


def get_wiki_locations():
    wiki_df = pd.read_csv(path_join("../../scripts/wiki", 
                                    "wiki_located_items_{}.csv".format(CITY)))

    wiki_df['street'] = wiki_df['roads']
    wiki_df = wiki_df.drop(columns=['roads'])
    wiki_df = wiki_df[wiki_df['street'] != '']

    wiki_df.views = wiki_df.views.astype(int)
    wiki_df.lon = wiki_df.lon.astype(float)
    wiki_df.lat = wiki_df.lat.astype(float)
    wiki_df['street'] = wiki_df['street'].astype(str)

    wiki_df['street'] = list(map(lambda x: x.title(), 
                                           wiki_df['street']))    
    
    stopwords = ['nazi']
    wiki_df = remove_stopwords(wiki_df, 'wiki_name', stopwords)
    
    return wiki_df


def get_street_wiki_views(wiki_df):
    street_wiki_df = wiki_df[['views', 'street']]

    street_wiki_df = street_wiki_df.groupby(['street'])\
                                   .sum()\
                                   .sort_values(by=['views'], ascending=False)\
                                   .reset_index()

    return {x: y for x, y in zip(street_wiki_df['street'], 
                                             street_wiki_df['views'])}


def get_insta_dict():
    insta_df = pd.read_csv(path_join(project_path, 
                         "scripts/top_places/top_places_{}.txt".format(CITY)), 
                         header=None)
    insta_df.columns = ['name', 'area', 'link', 'photos_counter']

    loc_id = []
    for x in insta_df.link:
        loc_id.append(x.split("/")[3])

    insta_df['id'] = loc_id

    # TEST ME
    insta_df = insta_df.drop([0])

    insta_df.id = insta_df.id.astype(int)
    geo_table.id = geo_table.id.astype(int)
    photos_top_streets = pd.merge(insta_df, geo_table, on='id') \
                                    [[STREET_COLUMN, 'photos_counter']]

    photos_top_streets = photos_top_streets.groupby([STREET_COLUMN])\
                                   .sum()\
                                   .sort_values(by=['photos_counter'], ascending=False)\
                                   .reset_index()

    photos_top_streets = photos_top_streets[photos_top_streets[STREET_COLUMN] != 'None']
    photos_top_streets['photos_counter'] = \
                        photos_top_streets['photos_counter'].astype(int)

    return {x: y for x, y in zip(photos_top_streets[STREET_COLUMN].tolist(), 
                                              photos_top_streets['photos_counter'] \
                                              .tolist())} 


def get_street_locs(wiki_locations_df):
    max_locs = 5
    
    grouped = wiki_locations_df[['street', 'wiki_name', 'views']].groupby('street')

    street_locs_wiki = {}
    for street,group in grouped:
        locs = list(zip(group.wiki_name.tolist(), group.views.tolist()))
        street_locs_wiki[street] = locs[:max_locs]

    return street_locs_wiki


def get_wiki_data():
    labels_wiki, short_labels = [], []
    xc, yc = [], []
    for z in street_insta_dict:
        if z in street_wiki_dict:
            short_labels.append(z)
            xc.append(street_insta_dict[z])
            yc.append(street_wiki_dict[z])
            labels_wiki.append('<i>{}</i><br>{}'.format(z, 
                                "<br>".join(map(tuple_to_str, 
                                                street_locs_wiki[z]))))
        else:
            continue

    wiki_data = {}
    for u, x, y, z in zip(short_labels, xc, yc, labels_wiki):
        wiki_data[u] = [x, y, z]
        
    return wiki_data

# %%
def insta_wiki_scatter(scatter_x1, scatter_y1, scatter_labels1):
    PLOT_HEIGHT = 400
    PLOT_WIDTH = 550
    
    data = [go.Scatter(x=scatter_x1, y=scatter_y1,
                       text=scatter_labels1,
                       mode = 'markers',
                       hoverinfo='text',
                       name='huge',
                       textfont=dict(size=8, color='lightgrey'),
                       marker=dict(color='dodgerblue', opacity=0.8)),
            ]

    min_x = np.min(scatter_x1)
    max_x = np.max(scatter_x1)
    med_x = np.median(scatter_x1)
    med_y = np.median(scatter_y1)
    
    shapes=[dict(type='line',
                 xref='x', yref='paper',
                 x0=med_x, y0=0,
                 x1=med_x, y1=1,
                 line=dict(color='grey', width=2, dash='dash')),
            dict(type='line',
                 xref='paper', yref='y',
                 x0=0, y0=med_y,
                 x1=1, y1=med_y,
                 line=dict(color='grey', width=2, dash='dash'))]

    layout = go.Layout(width=PLOT_WIDTH,
                       height=PLOT_HEIGHT,
                       margin = go.layout.Margin(t=30, b=50, l=50, r=30),
                       xaxis=dict(
                            title='insta', type='log',
                       ),
                       yaxis=dict(
                            title='wiki', type='log'),
                       hovermode='closest',
                       shapes=shapes,
                       showlegend=False)

    fig = go.Figure(data=data, layout=layout)
    py.iplot(fig, show_link=False)
    

wiki_df = get_wiki_locations()
street_wiki_dict = get_street_wiki_views(wiki_df)
street_insta_dict = get_insta_dict()  
street_locs_wiki = get_street_locs(wiki_df)
wiki_data = get_wiki_data()

insta_wiki_scatter([x[0] for x in wiki_data.values()],
                    [x[1] for x in wiki_data.values()],
                    [x[2] for x in wiki_data.values()])
# Out:
# <div id="eca99db5-4292-43e3-b11f-59dc08b27eb1" style="height: 400px; width: 550px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'eca99db5-4292-43e3-b11f-59dc08b27eb1',
#             [{"hoverinfo": "text", "marker": {"color": "dodgerblue", "opacity": 0.8}, "mode": "markers", "name": "huge", "text": ["<i>Piazza Del Colosseo</i><br>Colosseum, 2133252<br>Colosseo (Rome Metro..., 6868", "<i>Piazza Di Spagna</i><br>Spanish Steps, 328490<br>Piazza di Spagna, 60540<br>Babington's tea room, 9721<br>Fontana della Barcac..., 23768<br>Keats\u2013Shelley Memori..., 7896", "<i>Piazza Della Rotonda</i><br>Piazza della Rotonda, 15773<br>Fontana del Pantheon, 9430", "<i>Piazza Navona</i><br>Piazza Navona, 200052<br>Fontana dei Quattro ..., 93577<br>Stadium of Domitian, 20042", "<i>Lungotevere Castello</i><br>Castel Sant'Angelo, 300875", "<i>Via Della Salara Vecchia</i><br>Roman Forum, 485531<br>Forum of Caesar, 22192<br>Temple of Vesta, 51295", "<i>Piazza Del Popolo</i><br>Piazza del Popolo, 95407<br>Santa Maria del Popo..., 16790<br>Porta del Popolo, 10163", "<i>Piazza Venezia</i><br>Piazza Venezia, 89786", "<i>Piazza Del Campidoglio</i><br>Capitoline Museums, 80025<br>Capitoline Hill, 162152<br>Metropolitan City of..., 18741", "<i>Via Della Minerva</i><br>Pantheon, Rome, 1147785", "<i>Via Guido Reni</i><br>MAXXI, 47094", "<i>Via Del Corso</i><br>Via del Corso, 24191<br>San Marcello al Cors..., 9520", "<i>Via Del Teatro Di Marcello</i><br>Altare della Patria, 227378", "<i>Ponte Sant'Angelo</i><br>Ponte Sant'Angelo, 60912", "<i>Via Del Pellegrino</i><br>Campo de' Fiori, 80826", "<i>Viale De Coubertin Pietro</i><br>Parco della Musica, 14677", "<i>Piazza Pietro D'Illiria</i><br>Orange Garden, Rome, 15798<br>Santa Sabina, 49449", "<i>Via Tuscolana</i><br>Cinecitt\u00e0, 66050<br>Porta Furba - Quadra..., 1553<br>Anagnina (Rome Metro..., 5388<br>Giulio Agricola (Rom..., 1978<br>Lucio Sestio (Rome M..., 1207", "<i>Via Dei Condotti</i><br>Antico Caff\u00e8 Greco, 18465", "<i>Via Di San Gregorio</i><br>Palatine Hill, 219482", "<i>Viale Dei Gladiatori</i><br>Foro Italico, 28255<br>Italian Open (tennis..., 144033", "<i>Piazza Di Trevi</i><br>Trevi Fountain, 561619", "<i>Via Di Pietralata</i><br>Pietralata (Rome Met..., 1636", "<i>Via Flaminia</i><br>Unione Rugby Capitol..., 4519", "<i>Piazza Trilussa</i><br>Ponte Sisto, 13148", "<i>Piazza Camillo Benso Conte Di Cavour</i><br>Teatro Adriano, 1880", "<i>Belvedere Romolo E Remo</i><br>Circus Maximus, 271936", "<i>Via In Miranda</i><br>Regia, 27365", "<i>Viale Della Trinit\u00e0 Dei Monti</i><br>Villa Medici, 54462", "<i>Via Del Governo Vecchio</i><br>Santa Maria in Valli..., 14847", "<i>Piazza Della Bocca Della Verit\u00e0</i><br>Bocca della Verit\u00e0, 112507", "<i>Passeggiata Del Gianicolo</i><br>Villa Lante al Giani..., 6063", "<i>Via Del Circo Massimo</i><br>Circo Massimo (Rome ..., 3248", "<i>Via Margutta</i><br>Via Margutta, 8470", "<i>Via Di Ripetta</i><br>Ara Pacis, 111879<br>Via di Ripetta, 2160", "<i>Via Della Lungara</i><br>Villa Farnesina, 27281<br>Palazzo Corsini, Rom..., 13769<br>Santa Croce alla Lun..., 1079", "<i>Via Della Conciliazione</i><br>Via della Conciliazi..., 18069", "<i>Via Dei Fori Imperiali</i><br>Via dei Fori Imperia..., 20741", "<i>Piazza Della Minerva</i><br>Piazza della Minerva, 9013<br>Santa Maria sopra Mi..., 53511", "<i>Via Di San Nicola De' Cesarini</i><br>Largo di Torre Argen..., 58352", "<i>Piazza Grazioli</i><br>Doria Pamphilj Galle..., 28244", "<i>Via Giulia</i><br>Via Giulia, 6687", "<i>Via Appia Nuova</i><br>Capannelle Racecours..., 3991", "<i>Piazzale Ostiense</i><br>Pyramid of Cestius, 66206<br>Protestant Cemetery,..., 24581", "<i>Piazza Di Pietra</i><br>Temple of Hadrian, 22583", "<i>Via Di Santa Maria Dell'Anima</i><br>Sant'Agnese in Agone, 39111<br>Palazzo Pamphilj, 14412", "<i>Via Di Torre Argentina</i><br>Teatro Argentina, 11999", "<i>Via G. Garibaldi</i><br>Janiculum, 33093", "<i>Arco Della Pace</i><br>Chiostro del Bramant..., 3479", "<i>Piazza Colonna</i><br>Galleria Alberto Sor..., 9136<br>Piazza Colonna, 19282<br>Column of Marcus Aur..., 49282<br>Fontana di Piazza Co..., 2136", "<i>Piazza Di San Lorenzo In Lucina</i><br ...

# %% [markdown]
# ## Locations type

# %%
cn = Counter()
for loc in list(data1.keys()):
    for photo in data1[loc]:
        for category, val in data1[loc][photo]['categories'].items():
            cn[category] += float(val)

top_scenes = sorted(cn.items(), key=operator.itemgetter(1), reverse=True)[:N_SCENES]

tags = get_tags('selected', top_scenes)
scenes_result = sorted([[x, cn[x]] for x in tags], key=lambda x: x[1], reverse=True)

N_SKIP = 0
MAX_HOVER_LEN = 25

top_places = [relevant_places(key, 5) for key, _ in scenes_result][N_SKIP:]
id_list_to_name = lambda x: [trim(id2loc[y[0]], MAX_HOVER_LEN) for y in x]

# %%
fn3 = path_join(project_path, scenes_opposite_path)

with open(fn3, "r") as f:
    data3 = json.load(f)

cn = Counter()
for loc in list(data3.keys()):
    for photo in data3[loc]:
        for category, val in data3[loc][photo]['categories'].items():
            cn[category] += float(val)

scenes_result2 = sorted(cn.items(), key=operator.itemgetter(1), reverse=True)

d1 = {x[0]: x[1] / len(data1) for x in scenes_result}
d2 = {x[0]: x[1] / len(data3) for x in scenes_result2}

sc_delta_val = []
for x in d1:
    if x in d1 and x in d2:
        sc_delta_val.append([x, d1[x]-d2[x]])
    else:
        print("error", x, x in d1, x in d2)

sc_tags = [z[0] for z in sorted(scenes_result, key=lambda x: x[0])]

sc_delta = sorted(sc_delta_val, key=lambda x: abs(x[1]), reverse=True)[:25]
sc_delta = sorted(sc_delta, key=lambda x: x[1], reverse=False)

# %%
def tags_rate(bar_x, bar_y):
    FONT_SIZE = 11.5
    PLOT_WIDTH = 550
    PLOT_HEIGHT = 330
    VERTICAL_SPACING = 0.15
    RATE_BAR_COLOR = 'red' #'deeppink'
    TICKFONT_COLOR = 'lightgrey'
    MARGIN = go.layout.Margin(t=30, b=120, l=30, r=25)
    
    fig = tools.make_subplots(rows=1, cols=1, print_grid=False, 
                              horizontal_spacing=0.08,
                              vertical_spacing=VERTICAL_SPACING)
    # FIXME
    fig.append_trace(go.Bar(x=bar_x,
                            y=bar_y, opacity=0.9,
                            marker=dict(color=RATE_BAR_COLOR),
                            text=[" <br>".join(id_list_to_name(x)) 
                                                  for x in top_places],
                            hoverinfo="y+text"), 1,1)

    yaxis_style = dict(tickfont=dict(size=FONT_SIZE, color=TICKFONT_COLOR))
    xaxis_style = dict(tickfont=dict(size=FONT_SIZE, color=TICKFONT_COLOR), 
                       tickangle=-90)
    
    fig['layout'].update(height=PLOT_HEIGHT, width=PLOT_WIDTH,
                         yaxis1=yaxis_style, yaxis2=yaxis_style,
                         xaxis1=xaxis_style, xaxis2=xaxis_style,
                         margin=MARGIN, showlegend=False)

    py.iplot(fig, show_link=False)
    
    
def tags_delta(delta_bar_x, delta_bar_y):
    FONT_SIZE = 11.5
    PLOT_WIDTH = 550
    PLOT_HEIGHT = 330
    VERTICAL_SPACING = 0.15
    DELTA_BAR_COLOR = 'dodgerblue'
    TICKFONT_COLOR = 'lightgrey'
    MARGIN = go.layout.Margin(t=30, b=120, l=30, r=25)
    
    # FIXME
    fig = tools.make_subplots(rows=1, cols=1, print_grid=False, 
                              horizontal_spacing=0.08,
                              vertical_spacing=VERTICAL_SPACING)

    fig.append_trace(go.Bar(x=delta_bar_x,
                            y=delta_bar_y, opacity=0.9,
                            marker = dict(color=DELTA_BAR_COLOR)),1,1)

    yaxis_style = dict(tickfont=dict(size=FONT_SIZE, color=TICKFONT_COLOR))
    xaxis_style = dict(tickfont=dict(size=FONT_SIZE, color=TICKFONT_COLOR), 
                       tickangle=-90)
    
    fig['layout'].update(height=PLOT_HEIGHT, width=PLOT_WIDTH,
                         yaxis1=yaxis_style, yaxis2=yaxis_style,
                         xaxis1=xaxis_style, xaxis2=xaxis_style,
                         margin=MARGIN, showlegend=False)

    py.iplot(fig, show_link=False)

# %%
tags_rate([x[0].split("/")[0] for x in scenes_result][N_SKIP:],
                        [x[1] for x in scenes_result][N_SKIP:])
# Out:
# <div id="97b672ba-ec99-49ff-a737-cde9d7f8aa51" style="height: 330px; width: 550px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '97b672ba-ec99-49ff-a737-cde9d7f8aa51',
#             [{"hoverinfo": "y+text", "marker": {"color": "red"}, "opacity": 0.9, "text": ["H_M_Via_Del_Corso <br>Via_Flaminia_448_B_Ch_c_S... <br>Zara_Roma <br>Giulio_Verne <br>Dior_Roma", "Queen_Makeda_Grand_Pub <br>The_Jerry_Thomas_Project... <br>Jerry_Thomas_Speakeasy <br>Morrisons_Pub <br>THE_DRUNKEN_SHIP_OFFICIAL", "NICE_Disco <br>BARRIO_LATINO <br>Zaz_ <br>Sublime_Le_Colonial <br>El_Cid_Roma", "Mondadori_Bookstore <br>Scuola_dello_Sport_CONI <br>Le_M_ridien_Visconti_Rome <br>Hotel_Cicerone_Roma <br>Holiday_Inn_Rome_Eur_Parc...", "Via_Condotti <br>Via_dei_Condotti <br>Via_Del_Corso_ <br>Via_dei_Condotti <br>Castel_Sant_Angelo_Rome_I...", "Palatorrino <br>Ials_Roma <br>DAF_Dance_Arts_Faculty <br>Palestre_Passion_Fitness <br>Virgin_Active_EUR", "ZUM_Roma <br>Caff_Tazza_dOro <br>Sant_Eustachio_Il_Caff_ <br>Roscioli_Caff_ <br>Antico_Caff_Greco", "Museo_Palatino <br>Museo_Hendrik_Christian_A... <br>Palazzo_Cipolla_Mostra_Ba... <br>Guerra_Capitalismo_e_Libe... <br>Museo_Nazionale_Romano_Pa...", "Via_dei_Fori_Imperiali <br>Ponte_Sisto <br>SantAngelo_Rome <br>Castel_SantAngelo <br>Giardino_degli_Aranci", "Palazzo_Cipolla_Mostra_Ba... <br>Guerra_Capitalismo_e_Libe... <br>Palazzo_Cipolla_Mostra_Ba... <br>Palazzo_Corsini_Rome <br>Palazzo_Cipolla", "THE_DRUNKEN_SHIP_OFFICIAL <br>Blume_Lounge <br>Sciam <br>Club_Derri_re <br>Fingers_Roma", "Radio2 <br>El_Cid_Roma <br>Radio_Kaos_Italy <br>DEAR_Studi_Televisivi_Nom... <br>City_Dream", "Stadio_Olimpico_Di_Roma <br>Stadio_Olimpico_Roma <br>Olimpic_Stadium_Rome_Asro... <br>Stadio_Olimpico_Curva_Nor... <br>Curva_Sud", "Altroquando <br>Biblioteca_Angelica <br>Mondadori_Bookstore <br>Goody_music <br>Teatro_Quirino_Vittorio_G...", "True_Love_Shop <br>Massyedany_Cheapandchic <br>Georges_donna <br>Roma_Vintage_Boutique <br>Georges_uomo", "Family_tattoo_shop <br>Ultimi_Romantici_Tattoo <br>Galleria_Lorcan_ONeill_Ro... <br>Palazzo_Cipolla_Mostra_Ba... <br>Caligula_Tattoo_Studio", "Alfredo_alla_Scrofa_Roma... <br>Alfredo_alla_Scrofa <br>Collegio <br>Ristorante_Il_Vero_Alfred... <br>Ristorante_Due_Ladroni", "The_Jerry_Thomas_Project... <br>Morrisons_Pub <br>Club_Derri_re <br>Jerry_Thomas_Speakeasy <br>ARGOT", "Biblioteca_Angelica <br>Keats_Shelley_House_Rome <br>La_Veranda <br>Red_La_Feltrinelli_Roma <br>Santa_Maria_sopra_Minerva", "Giardino_degli_Aranci <br>Parco_Meda <br>Laghetto_Di_Villa_Ada <br>CAIO <br>Giardinetti", "Temple_of_Vesta <br>Via_Sacra <br>Roman_Forum_and_Palantine... <br>Temple_of_Saturn <br>Foro_Romano", "Policlinico_Tor_Vergata <br>Ponte_Regina_Margherita <br>Ripa <br>Stadio_delle_Terme_di_Car... <br>Tor_Vergata_Roma", "Aranciera_di_San_Sisto <br>Parco_Villa_Chigi_Roma_ <br>Parco_Viale_Tor_Di_Quinto <br>Riserva_naturale_Valle_de... <br>Salesian_Pontifical_Unive...", "Ponte_Vittorio_Emanuele_I... <br>Ponte_Sant_Angelo_Roma <br>River_Tiber <br>Ponte_Sant_Angelo <br>Ponte_de_Santo_ngelo", "Via_dei_Fori_Imperiali <br>Corviale <br>Foro_di_Cesare <br>Dal_Bolognese <br>Piazza_Zama"], "x": ["dressing_room", "beer_hall", "discotheque", "booth", "street", "martial_arts_gym", "coffee_shop", "museum", "promenade", "art_gallery", "pub", "television_studio", "stadium", "bookstore", "closet", "art_studio", "restaurant", "bar", "library", "picnic_area", "industrial_area", "highway", "lawn", "bridge", "skyscraper"], "y": [921.9721928505288, 624.984956306099, 575.1854402207795, 373.07223044929935, 357.23054018031877, 299.87252436652614, 233.44061697510017, 219.5958399307997, 171.400843582547, 165.41902203619978, 145.85852247550005, 144.25114002391422, 123.83239103226, 114.2870872552999, 112.99415152587291, 89.73794550772995, 89.06931952673501, 71.80190045902997, 53.41663967003994, 32.5572286728, 32.09391602940003, 31.022356043699997, 30.774261354999982, 22.414066027800008, 4.229789132999999], "type": "bar", "uid": "5e8a230a-2af7-11e9-8757-3c15c2cf2370", "xaxis": "x", "yaxis": "y"}],
#             {"xaxis": {"anchor": "y", "domain": [0.0, 1.0], "tickfont": {"size": 11.5, "color": "lightgrey"}, "tickangle": -90}, "yaxis": {"anchor": "x", "domain": [0.0, 1.0], "tickfont": {"size": 11.5, "color": "lightgrey"}}, "yaxis2": {"tickfont": {"size": 11.5, "color": "lightgrey"}}, "xaxis2": {"tickfont": {"size": 11.5, "color": "lightgrey"}, "tickangle": -90}, "margin": {"b": 120, "l": 30, "r": 25, "t": 30}, "height": 330, "width": 550, "showlegend": false},
#             {"showLink": false, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('97b672ba-ec99-49ff-a737-cde9d7f8aa51',{});}).then(function(){Plotly.animate('97b672ba-ec99-49ff-a737-cde9d7f8aa51');})
#         });</script>

# %%
sorted_tags = [x[0] for x in scenes_result]

def build_tags_table2():
    dd = []
    for loc in list(data1.keys()):
        cn = Counter()
        for photo in data1[loc]:
            for category, val in data1[loc][photo]['categories'].items():
                cn[category] += float(val)
        dd.append([loc, cn])

    dd1 = []
    for x in dd:
        dd1.append([x[0]] + [x[1][tag] for tag in tags])

    tags_table = pd.DataFrame(dd1)
    tags_table.columns=["id"] + tags
    
    return tags_table


def calculate_street_vectors(streets):
    keywords_table = build_tags_table2()
    street_vectors = []
    for s in streets:
        sv = np.zeros(N_SCENES)
        locations_id = geo_table[geo_table[STREET_COLUMN]==s]['id'].astype(str)
        for loc in locations_id:
            if loc in keywords_table.id.values:
                is_relevant = keywords_table['id']==loc
                relevant_row = keywords_table[is_relevant][sorted_tags]
                location_vector = relevant_row.iloc[0].tolist()
                sv += location_vector

        street_vectors.append(sv)
    
    return np.array(street_vectors)

# %%
def streets_features_plot(features_matrix, street_labels, tag_labels):
    FONT_SIZE = 11
    MAX_IM_VALUE = 24
    GRID_WIDTH = 0.9
    PLT_WIDTH = 9.5
    PLT_HEIGHT = 5.5
    PLOT_FACTOR = 0.7
    COLORMAP = 'Blues'
    LABEL_COLOR = 'grey'
    GRID_COLOR = 'white'
    CHINESE_RE = '[\u4e00-\u9fff]+'
    
    plt.figure(figsize=(PLT_WIDTH, PLT_HEIGHT))
    
    cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["aliceblue", "dodgerblue"])
    im = plt.imshow(features_matrix, 
                    cmap=cmap, vmax=MAX_IM_VALUE)

    ax = plt.gca()
    ax.set_xticks(np.arange(-0.5, N_SCENES, 1), minor=True)
    ax.set_yticks(np.arange(-0.5, TOP_STREETS_VIS, 1), minor=True)

    ax.tick_params(width=0)
    ax.tick_params(which="minor", width=0)

    for side in ['top', 'right', 'bottom', 'left']:
        ax.spines[side].set_visible(False)
    
    plt.grid(which="minor", color=GRID_COLOR, 
             linestyle='-', linewidth=GRID_WIDTH)

    if re.findall(CHINESE_RE, " ".join(street_labels)):
        warnings.warn("Chinese characters will be hide because of bad matplotlib support")
        street_labels = [re.sub(CHINESE_RE, '', x).strip() for x in street_labels]
    
    plt.xticks(range(N_SCENES), tag_labels, rotation=90, 
               size=FONT_SIZE, color=LABEL_COLOR)
    plt.yticks(range(TOP_STREETS_VIS), street_labels, 
               size=FONT_SIZE, color=LABEL_COLOR);
    
    
labels = [x.split("/")[0] for x in sorted_tags]
# FIXME
street_vectors = calculate_street_vectors(streets[:TOP_STREETS_VIS])
streets_features_plot(street_vectors, streets[:TOP_STREETS_VIS], labels)

# %%
def get_top_streets_tags():
    street_vectors = calculate_street_vectors(map_streets)

    street_tags = {}
    for u, v in zip(map_streets, street_vectors):
        sort = sorted(list(zip(labels[1:], v[1:])), 
                                                 key = lambda x: x[1], 
                                                 reverse=True)
        top = sort[0]
        val_sum = sum([x[1] for x in sort])
        street_tags[u] = [top[0], top[1]/val_sum]
    return street_tags


top_streets_tags = get_top_streets_tags()

# %%
def tagged_city_map(lat, lon, streets, streets_locations_number, tags_labels):
    MARKER_SIZE = 17
    MARKER_OPACITY = 0.3
    MARKER_COLOR = 'dodgerblue'
    ZOOM = 12
    MARGIN = dict(l=0, r=30, b=0, t=20)
    MAP_WIDTH = 700
    MAP_HEIGHT = 400
    MAX_MARKER_SIZE = 40
    MIN_MARKER_SIZE = 3
    FONT_SIZE = 12
    MIN_LOCATIONS = 5

    tags_labels = [x if streets_locations_number.iloc[j] > MIN_LOCATIONS
                   else "" for j, x in enumerate(tags_labels)]
    
    marker_sizes = [x if x < MAX_MARKER_SIZE else MAX_MARKER_SIZE 
                    for x in streets_locations_number]
    marker_sizes = [x if x > MIN_MARKER_SIZE else MIN_MARKER_SIZE
                    for x in marker_sizes]

    data = [go.Scattermapbox(
                lat=lat,
                lon=lon,
                mode='markers+text',
                marker=dict(
                    size=marker_sizes,
                    color=MARKER_COLOR,
                    opacity=MARKER_OPACITY),
                text=tags_labels,
                textfont=dict(size=FONT_SIZE),
                hoverinfo='none'
                )]

    layout = go.Layout(
                width=MAP_WIDTH,
                height=MAP_HEIGHT,
                hovermode='closest',
                margin=MARGIN,
                mapbox=dict(
                    accesstoken=MAPBOX_TOKEN,
                    center=dict(
                        lat=city_center[0],
                        lon=city_center[1]),
                    zoom=ZOOM,
                    style='light'
                ))

    fig = dict(data=data, layout=layout)
    py.iplot(fig, show_link=False)

    
tags_labels = []
for x in streets_table[STREET_COLUMN]:
    if np.isfinite(top_streets_tags[x][1]):
         tags_labels.append("{} {:.2f}".format(*top_streets_tags[x]))

tagged_city_map(streets_table['longtitude'], 
         streets_table['latitude'], 
         streets_table[STREET_COLUMN], 
         streets_table['counter'],
         tags_labels)
# Out:
# <div id="d225e7a2-f1a2-4683-91ff-61c9bf52beb2" style="height: 400px; width: 700px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d225e7a2-f1a2-4683-91ff-61c9bf52beb2", [{"hoverinfo": "none", "lat": [41.90583865045294, 41.90420041763549, 41.898913391773924, 41.91079089803637, 41.90287954990475, 41.89061297825, 41.85264196639444, 41.930973357606256, 41.89924516711875, 41.89603506830666, 41.89618345021428, 41.892557257853845, 41.89539239788182, 41.90472757279, 41.9017579033, 41.90529425596, 41.90095269137, 41.898197160989994, 41.93397713390001, 41.893212345500004, 41.815054114944445, 41.90850684209999, 41.9284845677125, 41.9072939989625, 41.906262777225, 41.89382166069999, 41.9335812128, 41.924524071300006, 41.89708015272857, 41.89559623955714, 41.89556008501428, 41.90906932627143, 41.89779213742857, 41.892221601349995, 41.90099370741667, 41.903703237933335, 41.90741316891667, 41.9419822301, 41.899983703483336, 41.908536328766665, 41.9045124146, 41.90593949893333, 41.89764943066667, 41.89877080106667, 41.92829558394, 41.899616949800006, 41.93422813626, 41.90051839798, 41.89177444164, 41.89289765668, 41.90534597094, 41.896097960400006, 41.93734491374, 41.90535037884, 41.87131464078, 41.897627566660006, 41.903349396799996, 41.9021534747, 41.90611996165, 41.902737215325004, 41.8994064456, 41.904421164125, 41.902568700125, 41.905734848550004, 41.89954363374999, 41.9000607098, 41.908915373125, 41.90864491905, 41.875835411875, 41.902164068475, 41.895777022225005, 41.894512129575006, 41.892409373999996, 41.897422013150006, 41.8942332921, 41.941861870375, 41.9316998516, 41.8949948625, 41.899208153100005, 41.8438311998, 41.89425286713333, 41.89766532543334, 41.899134585666665, 41.93889333333333, 41.9002839615, 41.8989752213, 41.93239966666666, 41.890255340866666, 41.893807752933334, 41.904249568333334, 41.93102663333334, 41.899518, 41.88121338883334, 41.8995588431, 41.9049002962, 41.8961345895, 41.89906130093333, 41.89261905906667, 41.894684959433334, 41.8870644912, 41.89643883643333, 41.93471307876667, 41.85059126636667, 41.901152413, 41.89597130923334, 41.8960957594, 41.95645153866667, 41.9338817841, 41.9513393487, 41.880950067700006, 41.899585923033335, 41.8917475444, 41.900315329166666, 41.90105271826667, 41.90539957199999, 41.92898327733334, 41.905109279166666, 41.85, 41.90680681, 41.90639810973333, 41.88321201653333, 41.933969491, 41.8938592859, 41.90013857809999, 41.92307058506666, 41.90075273636666, 41.85742150000001, 41.908297536633334, 41.900876022733335, 41.899008040000005, 41.90617608673333, 41.90461437346667, 41.91597008803333, 41.91089972213334, 41.889055, 41.903595300000006, 41.90020832645, 41.94495145725, 41.8852430128, 41.89796, 41.892269457750004, 41.91746675245, 41.9291569293, 41.8891114276, 41.9076394655, 41.8985805, 41.9105322889, 41.9093, 41.90229951795, 41.89559764185, 41.85285893895, 41.923344826, 41.85205522155, 41.8141372926, 41.905455, 41.928176651499996, 41.929469524249996, 41.828447752, 41.9011508354, 41.8979599563, 41.896924999999996, 41.93098096065, 41.94488670395, 41.883735441249996, 41.87794644725, 41.859044999999995, 41.899444444400004, 41.912386304, 41.9538413164, 41.92194219495, 41.88028018999999, 41.8088677616, 41.866776, 41.932582999999994, 41.9000526413, 41.9028693089, 41.864318, 41.85282155, 41.9009822522, 41.928931785050004, 41.907605546599996, 41.90578003515, 41.822876803949995, 41.90966416924999, 41.8941638889, 41.8997205254, 41.90080166665, 41.888120834649996, 41.9068454275, 41.89919836985, 41.905687703149994, 41.841225, 41.94866217975, 41.898279694850004, 41.91203945665, 41.88896858215, 41.8998901109, 41.862754267949995, 41.90513479495, 41.91898535475, 41.8813950503, 41.93665405829999, 41.9439872989, 41.89793495000001, 41.8521039182, 41.884903344099996, 41.90121925, 41.88806876335, 41.9430755424, 41.9385479969, 41.882355069599996, 41.8982929 ...

# %% [markdown]
# ## Cities comparing

# %%
# cities features compare

cn = Counter()
for loc in list(data1.keys()):
    for photo in data1[loc]:
        for category, val in data1[loc][photo]['categories'].items():
            cn[category] += float(val)
            
all_tags = list(cn.keys())

all_tags.remove("beauty_salon")
all_tags.remove("dressing_room")

####

def build_tags_table(tags, scene_data):
    dd = []
    for loc in list(scene_data.keys()):
        cn = Counter()
        location_data = scene_data[loc]
        for photo in location_data:
            photo_data = scene_data[loc][photo]['categories'].items()
            for category, val in photo_data:
                cn[category] += float(val) / len(location_data)
        dd.append([loc, cn])

    dd1 = []
    for x in dd:
        dd1.append([x[0]] + [x[1][tag] for tag in tags])

    tags_table = pd.DataFrame(dd1)
    tags_table.columns=["id"] + tags
    
    return tags_table


selected_tags = get_tags('selected')

opposite_scenes = load_json(path_join(project_path, scenes_opposite_path))
target_scenes = load_json(path_join(project_path, scenes_path))

opposite_tags_table = build_tags_table(selected_tags, opposite_scenes)
target_tags_table = build_tags_table(selected_tags, target_scenes)

general_tags_table = np.vstack((target_tags_table[selected_tags].values.tolist(), 
                                opposite_tags_table[selected_tags].values.tolist()))
####

visual_data = TSNE().fit_transform(general_tags_table).T

####

target_path = path_join(project_path, photos_path)
opposite_path = path_join(project_path, photos_opposite_path)

loc_file_target = list(map(lambda x: x.strip().split(","), 
                           open(target_path + "loc_info.csv", "r").readlines()[1:]))

id2loc_target = {x[0]: x[1] for x in loc_file_target}

loc_file_opposite = list(map(lambda x: x.strip().split(","), 
                             open(opposite_path + "loc_info.csv", "r").readlines()[1:]))

id2loc_opposite = {x[0]: x[1] for x in loc_file_opposite}

# %%
####

id2city = {}

for x in opposite_tags_table['id'].tolist():
    id2city[x] = opposite_city
    
for x in target_tags_table['id'].tolist():
    id2city[x] = CITY
    
####

def closest_node(node, nodes):
    nodes = np.asarray(nodes)
    dist_2 = np.sum((nodes - node)**2, axis=1)
    return np.argsort(dist_2)

vis_list = list(visual_data.T)
all_ids = target_tags_table['id'].tolist() + \
                opposite_tags_table['id'].tolist()

n_closest_samples = 10
proportion_threshold = 0.7
s = []
indexes_target, indexes_opposite, indexes_other = [], [], []
for j in range(len(visual_data[0])):
    xc, yc = visual_data[0, j], visual_data[1, j]
    
    f_v = vis_list[:j] + vis_list[j+1:]
    closest_nodes = closest_node((xc, yc), f_v)[:n_closest_samples]
    curr_city = id2city[all_ids[j]]
    locations_cities = [id2city[all_ids[x]] for x in closest_nodes]
    if locations_cities.count(curr_city) / len(locations_cities) > proportion_threshold:
        if curr_city == CITY:
            indexes_target.append(j)
        elif curr_city == opposite_city:   
            indexes_opposite.append(j)
    else:   
        indexes_other.append(j)

###

colors = np.array(['dodgerblue'] * target_tags_table.shape[0] + 
                  ['red'] * opposite_tags_table.shape[0])

for j in indexes_other:
    colors[j] = 'aliceblue'

labels = np.array(labels_target + labels_opposite)

####

# %%
def locations_scatter_plot(locs_x, locs_y, 
                           opposite_locs_x,opposite_locs_y,
                          locs_labels, opposite_locs_labels):
    MARKER_OPACITY = 0.4
    PLOT_HEIGHT = 400
    PLOT_WIDTH = 500
    TARGET_COLOR = 'red'
    OPPOSITE_COLOR = 'gold'
    MARGIN = dict(l=0, r=30, b=0, t=20)
    
    
    def create_scatter(x, y, colors, labels, name):
        return go.Scatter(x=x, y=y,
                          mode='markers',
                          hoverinfo='text', 
                          text=labels, name=name,
                          marker=dict(opacity=MARKER_OPACITY, 
                                       color=colors))
    
    data = [create_scatter(locs_x, locs_y, TARGET_COLOR, 
                           locs_labels, CITY),
            create_scatter(opposite_locs_x, opposite_locs_y, 
                           OPPOSITE_COLOR, opposite_locs_labels, 
                           opposite_city)]

    axis_style = dict(showticklabels=False, zeroline=False)
    layout = go.Layout(height=PLOT_HEIGHT, width=PLOT_WIDTH,
                        margin=MARGIN, hovermode='closest',
                        xaxis=axis_style, yaxis=axis_style)

    fig = go.Figure(data=data, layout=layout)

    py.iplot(fig, show_link=False)


locations_scatter_plot(np.array(visual_data[0])[indexes_target],
                       np.array(visual_data[1])[indexes_target], 
                       np.array(visual_data[0])[indexes_opposite],
                       np.array(visual_data[1])[indexes_opposite],
                       labels[indexes_target], labels[indexes_opposite])
# Out:
# <div id="5cdc8e00-8e58-4470-83c7-7268474075e6" style="height: 400px; width: 500px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '5cdc8e00-8e58-4470-83c7-7268474075e6',
#             [{"hoverinfo": "text", "marker": {"color": "red", "opacity": 0.4}, "mode": "markers", "name": "rome", "text": ["University of Rome T...<br>dressing_room, martial_arts_gym, lawn", "Positano Italy<br>promenade, street, beer_hall", "_", "Magliana Lazio Italy<br>dressing_room, martial_arts_gym, discotheque", "_", "Massyedany Cheapandc...<br>closet, dressing_room, martial_arts_gym", "Trullo Roma <br>dressing_room, booth, martial_arts_gym", "Colosseo Roma Italia<br>dressing_room, coffee_shop, martial_arts_gym", "Er Macellaio<br>dressing_room, booth, discotheque", "Colosseo<br>dressing_room, beer_hall, street", "Rione Testaccio<br>dressing_room, martial_arts_gym, art_gallery", "Altare della Patria<br>promenade, street, art_gallery", "Coliseu<br>street, promenade, martial_arts_gym", "Piramide Cestia<br>dressing_room, highway, promenade", "_", "Tiber Island<br>bridge, dressing_room, street", "Ristorante Consolini<br>dressing_room, beer_hall, restaurant", "Roma Vintage Boutiqu...<br>closet, dressing_room, museum", "Colliseum Rome Italy<br>street, lawn, closet", "Kolosseum<br>beer_hall, street, martial_arts_gym", "_", "Colosseum<br>dressing_room, promenade, martial_arts_gym", "Sinagoga Del Ghetto ...<br>promenade, street, library", "The Colloseum Rome I...<br>street, promenade, lawn", "Colosseum Coliseum R...<br>street, promenade, martial_arts_gym", "Basilica di Santa Ma...<br>street, promenade, dressing_room", "Antica Trattoria Da ...<br>coffee_shop, dressing_room, beer_hall", "Ristorante Riso<br>beer_hall, dressing_room, restaurant", "_", "Bocca della Verit <br>museum, street, dressing_room", "Ponte Fabricio<br>bridge, street, promenade", "Trattoria Sora Lella...<br>coffee_shop, dressing_room, booth", "Campidoglio<br>dressing_room, industrial_area, street", "Forum Romanum<br>street, promenade, industrial_area", "IED Istituto Europeo...<br>dressing_room, museum, library", "Teatro Della Cometa<br>dressing_room, television_studio, booth", "Statua Equestre di V...<br>museum, street, dressing_room", "Foro di Traiano<br>promenade, bookstore, booth", "Roma Collesium<br>martial_arts_gym, beer_hall, restaurant", "Rome<br>martial_arts_gym, beer_hall, restaurant", "Internazionali Bnl R...<br>martial_arts_gym, stadium, promenade", "Stadio Olympico Rome<br>stadium, discotheque, booth", "_", "Stadio Olimpico<br>stadium, martial_arts_gym, dressing_room", "Orange Futbolclub <br>stadium, martial_arts_gym, dressing_room", "Stadio Olimpico Di R...<br>stadium, martial_arts_gym, dressing_room", "Kaos Store<br>closet, dressing_room, martial_arts_gym", "Linda il merlo india...<br>dressing_room, martial_arts_gym, museum", "Olimpic Stadium Rome...<br>stadium, booth, discotheque", "Campo Centrale Inter...<br>stadium, martial_arts_gym, television_studio", "Internazionali BNL d...<br>martial_arts_gym, stadium, booth", "Stadio dei Marmi For...<br>stadium, museum, dressing_room", "_", "Internazionali Di Te...<br>martial_arts_gym, stadium, discotheque", "_", "Haus Garten<br>discotheque, beer_hall, pub", "Stadio Olimpico<br>stadium, discotheque, martial_arts_gym", "Stadio Olimpico<br>stadium, martial_arts_gym, discotheque", "Stadio dei Marmi<br>stadium, martial_arts_gym, promenade", "Stadio Olimpico Derb...<br>stadium, discotheque, dressing_room", "Stadio Olimpico Roma<br>stadium, martial_arts_gym, booth", "Stadio Olimpico Di R...<br>stadium, dressing_room, martial_arts_gym", "Foro Italico<br>martial_arts_gym, dressing_room, stadium", "_", "_", "_", "CONI Acqua Acetosa R...<br>stadium, dressing_room, martial_arts_gym", "Stadio Olimpico di R...<br>stadium, discotheque, martial_arts_gym", "Curva Sud ROMA<br>stadium, martial_arts_gym, discotheque", "Curva Nord Gabriele ...<br>stadium, martial_arts_gym, television_studio", "Tribuna autorit stad...<br>stadium, discotheque, martial_arts_gym", "Surplustore<br>dressing_room, martial_arts_gym, discotheque", "Convitto Nazionale V...<br>dressing_room, martial_arts_gym, booth", "Blume Lounge<br>beer_hall, pub, discot ...

# %%
tags_delta([x[0] for x in sc_delta], [x[1] for x in sc_delta])
# Out:
# <div id="55795089-e2a4-487f-961d-0d2afa8f7a12" style="height: 330px; width: 550px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '55795089-e2a4-487f-961d-0d2afa8f7a12',
#             [{"marker": {"color": "dodgerblue"}, "opacity": 0.9, "x": ["booth/indoor", "coffee_shop", "industrial_area", "skyscraper", "television_studio", "martial_arts_gym", "highway", "promenade", "art_studio", "bookstore", "picnic_area", "art_gallery", "street", "beer_hall", "lawn", "library/indoor", "bar", "restaurant", "bridge", "closet", "discotheque", "pub/indoor", "museum/indoor", "dressing_room", "stadium/soccer"], "y": [-0.13873944971679714, -0.10933056040652661, -0.07002987138419346, -0.06265236064413944, -0.062371875761877485, -0.06049217429676185, -0.05191680620676824, -0.04622523916990519, -0.04452361353892388, -0.030483053284860603, -0.023953673716392856, -0.02009994593421255, -0.01726567128053813, -0.015078091866951582, -0.009618682057303058, -0.007624083906659598, -0.002726722898336545, 0.0021855780498372807, 0.005498834703703489, 0.010812263437213449, 0.014262285254774743, 0.025548467810555392, 0.02782846163029193, 0.06196846619395113, 0.07938256517453463], "type": "bar", "uid": "026ea3cc-2af8-11e9-b83f-3c15c2cf2370", "xaxis": "x", "yaxis": "y"}],
#             {"xaxis": {"anchor": "y", "domain": [0.0, 1.0], "tickfont": {"size": 11.5, "color": "lightgrey"}, "tickangle": -90}, "yaxis": {"anchor": "x", "domain": [0.0, 1.0], "tickfont": {"size": 11.5, "color": "lightgrey"}}, "yaxis2": {"tickfont": {"size": 11.5, "color": "lightgrey"}}, "xaxis2": {"tickfont": {"size": 11.5, "color": "lightgrey"}, "tickangle": -90}, "margin": {"b": 120, "l": 30, "r": 25, "t": 30}, "height": 330, "width": 550, "showlegend": false},
#             {"showLink": false, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('55795089-e2a4-487f-961d-0d2afa8f7a12',{});}).then(function(){Plotly.animate('55795089-e2a4-487f-961d-0d2afa8f7a12');})
#         });</script>
